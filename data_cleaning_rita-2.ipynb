# %%
# !pip install obspy
# Out:
# Collecting obspy
#   Downloading obspy-1.4.0.tar.gz (17.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.0/17.0 MB 20.9 MB/s eta 0:00:0000:0100:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy>=1.20 in /Users/margarita.shnaider/anaconda3/lib/python3.11/site-packages (from obspy) (1.24.3)
# Requirement already satisfied: scipy>=1.7 in /Users/margarita.shnaider/anaconda3/lib/python3.11/site-packages (from obspy) (1.11.1)
# Requirement already satisfied: matplotlib>=3.3 in /Users/margarita.shnaider/anaconda3/lib/python3.11/site-packages (from obspy) (3.7.2)
# Requirement already satisfied: lxml in /Users/margarita.shnaider/anaconda3/lib/python3.11/site-packages (from obspy) (4.9.3)
# Requirement already satisfied: setuptools in /Users/margarita.shnaider/anaconda3/lib/python3.11/site-packages (from obspy) (68.0.0)
# Requirement already satisfied: sqlalchemy in /Users/margarita.shnaider/anaconda3/lib/python3.11/site-packages (from obspy) (1.4.39)
# Requirement already satisfied: decorator in /Users/margarita.shnaider/anaconda3/lib/python3.11/site-packages (from obspy) (5.1.1)
# Requirement already satisfied: requests in /Users/margarita.shnaider/anaconda3/lib/python3.11/site-packages (from obspy) (2.31.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/margarita.shnaider/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.3->obspy) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /Users/margarita.shnaider/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.3->obspy) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/margarita.shnaider/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.3->obspy) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/margarita.shnaider/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.3->obspy) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/margarita.shnaider/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.3->obspy) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /Users/margarita.shnaider/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.3->obspy) (9.4.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /Users/margarita.shnaider/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.3->obspy) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/margarita.shnaider/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.3->obspy) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/margarita.shnaider/anaconda3/lib/python3.11/site-packages (from requests->obspy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/margarita.shnaider/anaconda3/lib/python3.11/site-packages (from requests->obspy) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/margarita.shnaider/anaconda3/lib/python3.11/site-packages (from requests->obspy) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/margarita.shnaider/anaconda3/lib/python3.11/site-packages (from requests->obspy) (2023.7.22)
# Requirement already satisfied: six>=1.5 in /Users/margarita.shnaider/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=3.3->obspy) (1.16.0)
# Building wheels for collected packages: obspy
#   Building wheel for obspy (pyproject.toml) ... done
#   Created wheel for obspy: filename=obspy-1.4.0-cp311-cp311-macosx_11_0_arm64.whl size=14045226 sha256=b0660081d6f694270872ea7d7e0804ea8de4fc8e4427417623c4a5c2a30c861b
#   Stored in directory: /Users/margarita.shnaider/Library/Caches/pip/wheels/8b/7d/9b/c21e4534fec78fd69a71b5bbcc6017fcaccaf618a482f77212
# Successfully built obspy
# Installing collected packages: obspy
# Successfully installed obspy-1.4.0

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
from obspy.signal.detrend import polynomial
import obspy

# %%
#list the files
filelist = os.listdir("rr_data")
#read them into pandas
df_list = [pd.read_csv(f'rr_data/{file}',delimiter = "\t",names=[f'{file}']) for file in filelist]
print(df_list)
# Out:
# [        003.txt
# 0           718
# 1           672
# 2           688
# 3           672
# 4           664
# ...         ...
# 108145      555
# 108146      547
# 108147      539
# 108148      531
# 108149      531
#
# [108150 rows x 1 columns],        002.txt
# 0          735
# 1          781
# 2          742
# 3          680
# 4          758
# ...        ...
# 68024      524
# 68025      593
# 68026      602
# 68027      672
# 68028      672
#
# [68029 rows x 1 columns],        000.txt
# 0          789
# 1          727
# 2          789
# 3          750
# 4          812
# ...        ...
# 80436      649
# 80437      695
# 80438      727
# 80439      703
# 80440      703
#
# [80441 rows x 1 columns],         011.txt
# 0           539
# 1           539
# 2           547
# 3           539
# 4           539
# ...         ...
# 110506      781
# 110507      773
# 110508      813
# 110509      843
# 110510      843
#
# [110511 rows x 1 columns],        005.txt
# 0          797
# 1          843
# 2          829
# 3          828
# 4          859
# ...        ...
# 97920      766
# 97921      797
# 97922      781
# 97923      750
# 97924      750
#
# [97925 rows x 1 columns],        010.txt
# 0          984
# 1          969
# 2          969
# 3          922
# 4          937
# ...        ...
# 82075      961
# 82076     1015
# 82077     1071
# 82078     1054
# 82079     1054
#
# [82080 rows x 1 columns],        006.txt
# 0          844
# 1          813
# 2          781
# 3          773
# 4          789
# ...        ...
# 89619      813
# 89620      820
# 89621      844
# 89622      852
# 89623      852
#
# [89624 rows x 1 columns],         013.txt
# 0           664
# 1           665
# 2           656
# 3           672
# 4           672
# ...         ...
# 111516      649
# 111517      648
# 111518      641
# 111519      632
# 111520      632
#
# [111521 rows x 1 columns],        007.txt
# 0          704
# 1          710
# 2          727
# 3          734
# 4          735
# ...        ...
# 57328      672
# 57329      641
# 57330      640
# 57331      649
# 57332      649
#
# [57333 rows x 1 columns],        009.txt
# 0          641
# 1          633
# 2          640
# 3          657
# 4          648
# ...        ...
# 67258      805
# 67259      883
# 67260      781
# 67261      742
# 67262      742
#
# [67263 rows x 1 columns],       008.txt
# 0         758
# 1         774
# 2         789
# 3         781
# 4         687
# ...       ...
# 98212     836
# 98213     851
# 98214     852
# 98215     852
# 98216       @
#
# [98217 rows x 1 columns]]

# %%
min_len = min(map(len, df_list))
print(min_len)
#to even the all txt files cropping them
small_df = pd.concat(df_list,axis=1)
big_df = (small_df.T).apply(pd.to_numeric, errors='coerce')
cropped_df = big_df.iloc[:,:min_len]
print(cropped_df)
# Out:
# 57333
#          0      1      2      3      4      5      6       7      8      \
# 003.txt  718.0  672.0  688.0  672.0  664.0  625.0  617.0   617.0  617.0
# 002.txt  735.0  781.0  742.0  680.0  758.0  695.0  680.0   679.0  625.0
# 000.txt  789.0  727.0  789.0  750.0  812.0  789.0  828.0   797.0  867.0
# 011.txt  539.0  539.0  547.0  539.0  539.0  531.0  539.0   539.0  539.0
# 005.txt  797.0  843.0  829.0  828.0  859.0  859.0  875.0   875.0  922.0
# 010.txt  984.0  969.0  969.0  922.0  937.0  961.0  992.0  1000.0  930.0
# 006.txt  844.0  813.0  781.0  773.0  789.0  797.0  797.0   758.0  727.0
# 013.txt  664.0  665.0  656.0  672.0  672.0  656.0  656.0   641.0  601.0
# 007.txt  704.0  710.0  727.0  734.0  735.0  719.0  710.0   719.0  703.0
# 009.txt  641.0  633.0  640.0  657.0  648.0  649.0  632.0   633.0  641.0
# 008.txt  758.0  774.0  789.0  781.0  687.0  672.0  680.0   727.0  836.0
#
#          9      ...   57323   57324   57325   57326   57327   57328   57329  \
# 003.txt  633.0  ...   836.0   805.0   789.0   766.0   789.0   820.0   820.0
# 002.txt  657.0  ...   821.0   851.0   782.0   804.0   680.0   797.0  1164.0
# 000.txt  860.0  ...   992.0  1062.0  1024.0  1055.0  1023.0  1102.0  1007.0
# 011.txt  539.0  ...   516.0   531.0   523.0   539.0   532.0   539.0   523.0
# 005.txt  875.0  ...   984.0   914.0   938.0   906.0   930.0   805.0  1140.0
# 010.txt  914.0  ...  1039.0  1078.0  1117.0  1086.0  1094.0  1125.0  1109.0
# 006.txt  703.0  ...   906.0   844.0   844.0   828.0   883.0   961.0  1054.0
# 013.txt  610.0  ...   828.0   875.0   922.0   906.0   860.0   828.0   867.0
# 007.txt  688.0  ...   625.0   640.0   664.0   664.0   641.0   672.0   641.0
# 009.txt  625.0  ...   922.0   899.0   843.0   883.0   938.0   859.0   914.0
# 008.txt  914.0  ...  1133.0  1132.0  1079.0  1117.0  1101.0  1008.0   969.0
#
#           57330   57331   57332
# 003.txt   790.0   742.0   726.0
# 002.txt  1062.0   993.0  1234.0
# 000.txt  1078.0  1094.0  1016.0
# 011.txt   524.0   531.0   523.0
# 005.txt   953.0  1008.0  1078.0
# 010.txt  1079.0  1093.0  1094.0
# 006.txt  1055.0  1062.0  1063.0
# 013.txt   891.0   914.0   844.0
# 007.txt   640.0   649.0   649.0
# 009.txt   883.0   898.0   836.0
# 008.txt  1000.0  1086.0  1015.0
#
# [11 rows x 57333 columns]

# %%
#separating the dataframe into 2 batches
batch1 = cropped_df.iloc[:,:int(cropped_df.shape[1]/2)]
batch2 = cropped_df.iloc[:,int(cropped_df.shape[1]/2):]
print(batch1)
print(batch2)
# Out:
#          0      1      2      3      4      5      6       7      8      \
# 003.txt  718.0  672.0  688.0  672.0  664.0  625.0  617.0   617.0  617.0
# 002.txt  735.0  781.0  742.0  680.0  758.0  695.0  680.0   679.0  625.0
# 000.txt  789.0  727.0  789.0  750.0  812.0  789.0  828.0   797.0  867.0
# 011.txt  539.0  539.0  547.0  539.0  539.0  531.0  539.0   539.0  539.0
# 005.txt  797.0  843.0  829.0  828.0  859.0  859.0  875.0   875.0  922.0
# 010.txt  984.0  969.0  969.0  922.0  937.0  961.0  992.0  1000.0  930.0
# 006.txt  844.0  813.0  781.0  773.0  789.0  797.0  797.0   758.0  727.0
# 013.txt  664.0  665.0  656.0  672.0  672.0  656.0  656.0   641.0  601.0
# 007.txt  704.0  710.0  727.0  734.0  735.0  719.0  710.0   719.0  703.0
# 009.txt  641.0  633.0  640.0  657.0  648.0  649.0  632.0   633.0  641.0
# 008.txt  758.0  774.0  789.0  781.0  687.0  672.0  680.0   727.0  836.0
#
#          9      ...   28656   28657   28658   28659   28660   28661   28662  \
# 003.txt  633.0  ...   820.0   812.0   774.0   742.0   703.0   680.0   664.0
# 002.txt  657.0  ...   954.0   921.0   961.0   946.0   929.0  1008.0   977.0
# 000.txt  860.0  ...  1023.0  1032.0  1008.0   945.0   922.0  1000.0   961.0
# 011.txt  539.0  ...   539.0   516.0   516.0   507.0   516.0   500.0   492.0
# 005.txt  875.0  ...   664.0   602.0   609.0   602.0   586.0   578.0   562.0
# 010.txt  914.0  ...  1125.0  1148.0  1094.0  1117.0  1055.0   968.0   985.0
# 006.txt  703.0  ...   750.0   742.0   758.0   789.0   797.0   796.0   797.0
# 013.txt  610.0  ...   718.0   727.0   742.0   734.0   704.0   695.0   695.0
# 007.txt  688.0  ...   649.0   656.0   672.0   703.0   688.0   703.0   734.0
# 009.txt  625.0  ...  1156.0  1187.0  1086.0  1164.0  1203.0  1118.0  1086.0
# 008.txt  914.0  ...   711.0   664.0   664.0   641.0   664.0   640.0   641.0
#
#           28663   28664   28665
# 003.txt   648.0   664.0   711.0
# 002.txt   945.0  1008.0   922.0
# 000.txt  1015.0   985.0  1000.0
# 011.txt   492.0   493.0   500.0
# 005.txt   571.0   570.0   570.0
# 010.txt  1008.0   992.0  1031.0
# 006.txt   782.0   757.0   758.0
# 013.txt   696.0   687.0   680.0
# 007.txt   734.0   743.0   711.0
# 009.txt  1164.0  1156.0  1062.0
# 008.txt   641.0   617.0   601.0
#
# [11 rows x 28666 columns]
#           28666   28667   28668   28669   28670   28671   28672   28673  \
# 003.txt   766.0   828.0   789.0   750.0   781.0   829.0   835.0   821.0
# 002.txt   945.0   984.0   969.0  1024.0  1007.0   961.0  1000.0  1000.0
# 000.txt   961.0   921.0   969.0   977.0   890.0   891.0   914.0   891.0
# 011.txt   500.0   523.0   523.0   532.0   531.0   531.0   524.0   523.0
# 005.txt   594.0   602.0   632.0   633.0   688.0   664.0   679.0   688.0
# 010.txt  1023.0   993.0  1007.0  1079.0  1046.0  1071.0  1062.0   992.0
# 006.txt   750.0   750.0   750.0   735.0   742.0   750.0   758.0   757.0
# 013.txt   672.0   664.0   656.0   648.0   618.0   632.0   641.0   664.0
# 007.txt   679.0   672.0   680.0   640.0   657.0   664.0   664.0   711.0
# 009.txt  1172.0  1203.0  1078.0  1165.0  1179.0  1102.0  1117.0  1195.0
# 008.txt   610.0   617.0   625.0   617.0   602.0   609.0   578.0   586.0
#
#           28674   28675  ...   57323   57324   57325   57326   57327   57328  \
# 003.txt   750.0   734.0  ...   836.0   805.0   789.0   766.0   789.0   820.0
# 002.txt   930.0   969.0  ...   821.0   851.0   782.0   804.0   680.0   797.0
# 000.txt   929.0   914.0  ...   992.0  1062.0  1024.0  1055.0  1023.0  1102.0
# 011.txt   523.0   524.0  ...   516.0   531.0   523.0   539.0   532.0   539.0
# 005.txt   641.0   656.0  ...   984.0   914.0   938.0   906.0   930.0   805.0
# 010.txt  1055.0  1078.0  ...  1039.0  1078.0  1117.0  1086.0  1094.0  1125.0
# 006.txt   774.0   781.0  ...   906.0   844.0   844.0   828.0   883.0   961.0
# 013.txt   703.0   711.0  ...   828.0   875.0   922.0   906.0   860.0   828.0
# 007.txt   679.0   688.0  ...   625.0   640.0   664.0   664.0   641.0   672.0
# 009.txt  1149.0  1062.0  ...   922.0   899.0   843.0   883.0   938.0   859.0
# 008.txt   586.0   586.0  ...  1133.0  1132.0  1079.0  1117.0  1101.0  1008.0
#
#           57329   57330   57331   57332
# 003.txt   820.0   790.0   742.0   726.0
# 002.txt  1164.0  1062.0   993.0  1234.0
# 000.txt  1007.0  1078.0  1094.0  1016.0
# 011.txt   523.0   524.0   531.0   523.0
# 005.txt  1140.0   953.0  1008.0  1078.0
# 010.txt  1109.0  1079.0  1093.0  1094.0
# 006.txt  1054.0  1055.0  1062.0  1063.0
# 013.txt   867.0   891.0   914.0   844.0
# 007.txt   641.0   640.0   649.0   649.0
# 009.txt   914.0   883.0   898.0   836.0
# 008.txt   969.0  1000.0  1086.0  1015.0
#
# [11 rows x 28667 columns]

# %%
def reject_outliers(data):
    cleaned_rows = np.zeros((data.shape[0],data.shape[1]))
    N = data.shape[0]
    for i in range(N):
        
        row_data = data.iloc[i, :]

        row_mean = np.mean(row_data)
        row_std = np.std(row_data)
    
        threshold = 3
        lower_bound = row_mean - threshold * row_std
        upper_bound = row_mean + threshold * row_std
    
        outliers = np.logical_or(row_data < lower_bound, row_data > upper_bound)
    
        cleaned_row = np.where(outliers, np.nan, row_data)
        
        cleaned_rows[i,:] = np.array(cleaned_row)

    cleaned_data = np.array(cleaned_rows)
    return cleaned_data

batch1_clean = reject_outliers(batch1)
plt.plot(batch1_clean[0,:], color = 'black', linewidth=0.2)
plt.title('Batch 1')
plt.xlabel('Beats')
plt.ylabel('Interbeat interval, msec')
plt.show()

plt.plot(batch1_clean[1,:], color = 'black', linewidth=0.2)
plt.show()

plt.plot(batch1_clean[2,:], color = 'black', linewidth=0.1)
plt.show()


batch2_clean = reject_outliers(batch2)
plt.plot(batch2_clean[0,:], color = 'black', linewidth=0.1)
plt.title('Batch 2')
plt.xlabel('Beats')
plt.ylabel('Interbeat interval, msec')
plt.show()

plt.plot(batch2_clean[1,:], color = 'black', linewidth=0.1)
plt.show()

plt.plot(batch2_clean[2,:], color = 'black', linewidth=0.1)
plt.show()

# %%
#Detrending
def detrend(df, s_vals, p_order):
    N = int(np.floor(df.shape[1]/s_vals[-1]))
    no_pats= df.shape[0]
    Delta_S_B=np.zeros((len(s_vals),N,no_pats))
    for j in range(no_pats):
      row = df.iloc[j,:]
      for idx, s in enumerate(s_vals):
        intval = int(np.floor(N/(2*s)))
        detrended_row = np.zeros(df.shape[1])
        for i in range(intval):
          detrended_row[i * 2 * s: (i + 1) * 2 * s] = polynomial(row[i * 2 * s: (i + 1) * 2 * s], p_order, plot=False)
          #polynomial(row[i*2*s:(i+1)*2*s],p_order, plot =False)    
        #polynomial(row[i*2*s:(i+1)*2*s],p_order, plot =False)
        detrended_row[intval*2*s:] = polynomial(row[intval*2*s:], p_order, plot=False)
        Delta_S_B[idx,:,j]=np.array([detrended_row[i+s]-detrended_row[i] for i in range(N)])
        #Delta_S_B[idx,:,j]=np.array([row[i+s]-row[i] for i in range(N)])
        
      # Normalize Delta_S_B for each patient
      std = np.std(Delta_S_B[:, :, j], axis=1)
      Delta_S_B[:, :, j] /= std[:, None] 
    return Delta_S_B
